# %% [markdown]
# <a href="https://colab.research.google.com/github/iftikhar200/DEV1/blob/main/seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install seaborn
# !pip install numpy
# !pip install pandas

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/titanic_dataset.csv',index_col="Name")
df.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %%
sns.relplot(data=df,x="Age",y="Fare",hue="Sex",kind="line",col="Pclass")

# %%
sns.countplot(x='Sex', hue='Survived', data=df)
plt.title("Survival by Gender")
plt.show()

# %%
sns.boxplot(x='Pclass', y='Fare',data=df)
plt.title("Fare Distribution by Passenger Class")
plt.show()

# %%
sns.scatterplot(x="Age", y="Fare", data=df, hue="Survived")
plt.title("Age vs. Fare with Survival")
# Out:
# Text(0.5, 1.0, 'Age vs. Fare with Survival')

# %%
sns.scatterplot(x="Age", y="Fare", data=df, hue="Sex")
plt.title("Age vs. Fare with Sex")
# Out:
# Text(0.5, 1.0, 'Age vs. Fare with Sex')

# %%
sns.lineplot(x="Age", y="Fare", data=df, hue="Sex")
plt.title("Age vs. Fare with sex")
# Out:
# Text(0.5, 1.0, 'Age vs. Fare with sex')

# %%
sns.barplot(x="Sex", y="Survived", data=df,hue="Pclass" )
plt.title("Fare by Passenger Class and Sex")
# Out:
# Text(0.5, 1.0, 'Fare by Passenger Class and Sex')

# %%
sns.stripplot(x="Sex", y="Age", data=df,hue="Sex")
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.swarmplot(x="Sex", y="Age", data=df,hue="Sex")
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.swarmplot(x="Survived", y="Age", data=df,hue="Sex")
plt.title("Age Distribution of Survivors and Non-Survivors by Gender")
# Out:
# Text(0.5, 1.0, 'Age Distribution of Survivors and Non-Survivors by Gender')
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 5.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
