# %% [markdown]
# <a href="https://colab.research.google.com/github/iftikhar200/DEV1/blob/main/ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv("http://bit.ly/imdbratings",sep=",",index_col="title")
df.shape
df.dtypes
# Out:
# star_rating       float64
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
df.shape
# Out:
# (979, 6)

# %%
df.head()
# Out:
#                           star_rating content_rating   genre  duration  \
# title
# The Shawshank Redemption          9.3              R   Crime       142
# The Godfather                     9.2              R   Crime       175
# The Godfather: Part II            9.1              R   Crime       200
# The Dark Knight                   9.0          PG-13  Action       152
# Pulp Fiction                      8.9              R   Crime       154
#
#                                                                 actors_list
# title
# The Shawshank Redemption  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# The Godfather               [u'Marlon Brando', u'Al Pacino', u'James Caan']
# The Godfather: Part II    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# The Dark Knight           [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# Pulp Fiction              [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df['star_rating'].describe()
# Out:
# count    979.000000
# mean       7.889785
# std        0.336069
# min        7.400000
# 25%        7.600000
# 50%        7.800000
# 75%        8.100000
# max        9.300000
# Name: star_rating, dtype: float64

# %%
df.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
df.iloc[20]
# Out:
# star_rating                                                     8.7
# content_rating                                                    R
# genre                                                        Action
# duration                                                        136
# actors_list       [u'Keanu Reeves', u'Laurence Fishburne', u'Car...
# Name: The Matrix, dtype: object

# %%
df.loc["The Shawshank Redemption"]
# Out:
# star_rating                                                     9.3
# content_rating                                                    R
# genre                                                         Crime
# duration                                                        142
# actors_list       [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# Name: The Shawshank Redemption, dtype: object

# %%
df.sort_values("star_rating",ascending=False)
# Out:
#                           star_rating content_rating   genre  duration  \
# title
# The Shawshank Redemption          9.3              R   Crime       142
# The Godfather                     9.2              R   Crime       175
# The Godfather: Part II            9.1              R   Crime       200
# The Dark Knight                   9.0          PG-13  Action       152
# Pulp Fiction                      8.9              R   Crime       154
# ...                               ...            ...     ...       ...
# Frances Ha                        7.4              R  Comedy        86
# Home Alone                        7.4             PG  Comedy       103
# Bound                             7.4              R   Crime       108
# Sleepy Hollow                     7.4              R   Drama       105
# Wall Street                       7.4              R   Crime       126
#
#                                                                 actors_list
# title
# ...

# %%
df[df["genre"]=="Crime"]
# Out:
#                           star_rating content_rating  genre  duration  \
# title
# The Shawshank Redemption          9.3              R  Crime       142
# The Godfather                     9.2              R  Crime       175
# The Godfather: Part II            9.1              R  Crime       200
# Pulp Fiction                      8.9              R  Crime       154
# City of God                       8.7              R  Crime       130
# ...                               ...            ...    ...       ...
# Brick                             7.5              R  Crime       110
# Mean Streets                      7.4              R  Crime       112
# Bound                             7.4              R  Crime       108
# Law Abiding Citizen               7.4              R  Crime       109
# Wall Street                       7.4              R  Crime       126
#
#                                                                 actors_list
# title
# ...
